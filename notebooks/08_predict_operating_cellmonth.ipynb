# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import sys
from pathlib import Path

# Add the project root to the Python path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

# Set up matplotlib for inline plotting
# %matplotlib inline

def load_and_preprocess_data(file_path):
    df = pd.read_csv(file_path)
    df['Adjusted Date'] = pd.to_datetime(df['Adjusted Date'])
    df = df.sort_values('Adjusted Date')
    
    # Filter for specified date range and geounits
    df = df[(df['Adjusted Date'] >= '2023-01-01') & 
            (df['Adjusted Date'] <= '2024-06-30') &
            (df['Sl Geounit (Code)'].isin(['APG', 'QTG', 'ECP', 'NAO']))]
    
    categorical_features = ['Country Name', 'Billing Account', 'Rig Name', 'Well type']
    df[categorical_features] = df[categorical_features].fillna('Unknown')
    
    return df, categorical_features

file_path = project_root / "processed_data" / "processed_tickets_wles_ops_data.csv"
full_df, categorical_features = load_and_preprocess_data(file_path)

def train_and_predict(train_df, test_df, categorical_features):
    X_train = train_df[categorical_features + ['Unique_Well_Count']]
    y_train = train_df['Operating_CellMonth']
    X_test = test_df[categorical_features + ['Unique_Well_Count']]
    y_test = test_df['Operating_CellMonth']

    model = CatBoostRegressor(cat_features=categorical_features, random_state=42)
    model.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50, verbose=100)

    test_preds = model.predict(X_test)

    return model, test_preds

def create_operating_cellmonth_plot(geounit_df, geounit):
    geounit_df['Quarter'] = geounit_df['Adjusted Date'].dt.to_period('Q')
    
    train_df = geounit_df[geounit_df['Adjusted Date'] <= '2023-12-31']
    test_df = geounit_df[geounit_df['Adjusted Date'] >= '2024-01-01']
    
    model, test_preds = train_and_predict(train_df, test_df, categorical_features)
    
    test_df['Predicted'] = test_preds

    quarterly_full = geounit_df.groupby('Quarter').agg({
        'Operating_CellMonth': 'sum'
    }).reset_index()

    quarterly_test = test_df.groupby('Quarter').agg({
        'Operating_CellMonth': 'sum',
        'Predicted': 'sum'
    }).reset_index()

    quarterly_test['Percentage_Error'] = ((quarterly_test['Predicted'] - quarterly_test['Operating_CellMonth']) / quarterly_test['Operating_CellMonth']) * 100

    fig, ax = plt.subplots(figsize=(15, 8))

    # Plot actual Operating CellMonth for the entire timeline (2022-10-01 to 2024-06-30)
    ax.plot(quarterly_full['Quarter'].astype(str), quarterly_full['Operating_CellMonth'], label='Actual', marker='o', color='blue')

    # Plot predicted Operating CellMonth for the test period
    ax.plot(quarterly_test['Quarter'].astype(str), quarterly_test['Predicted'], label='Predicted (Test)', marker='s', color='green', linestyle=':')

    ax.set_title(f'Actual vs Predicted Operating CellMonth by Quarter ({geounit} Geounit)')
    ax.set_xlabel('Quarter')
    ax.set_ylabel('Operating CellMonth')
    ax.legend()
    ax.tick_params(axis='x', rotation=45)

    # Add percentage error annotations for test period
    for i, row in quarterly_test.iterrows():
        ax.annotate(f"{row['Percentage_Error']:.2f}%", 
                    (str(row['Quarter']), row['Predicted']),
                    textcoords="offset points", 
                    xytext=(0,10), 
                    ha='center')

    plt.tight_layout()
    plt.show()

    print(f"Quarterly Test Data for {geounit}:")
    print(quarterly_test)

    return model

# Create plots for each geounit
geounits = ['APG', 'QTG', 'ECP', 'NAO']
models = {}

for geounit in geounits:
    geounit_df = full_df[full_df['Sl Geounit (Code)'] == geounit]
    models[geounit] = create_operating_cellmonth_plot(geounit_df, geounit)

# Model Feature Importance for each geounit
for geounit, model in models.items():
    feature_importance = model.feature_importances_
    feature_names = categorical_features + ['Unique_Well_Count']

    feature_importance_df = pd.DataFrame({'feature': feature_names, 'importance': feature_importance})
    feature_importance_df = feature_importance_df.sort_values('importance', ascending=False)

    plt.figure(figsize=(10, 6))
    plt.bar(feature_importance_df['feature'], feature_importance_df['importance'])
    plt.title(f'Feature Importance for Operating CellMonth Prediction ({geounit} Geounit)')
    plt.xlabel('Features')
    plt.ylabel('Importance')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

    print(f"\nFeature Importance for {geounit}:")
    print(feature_importance_df)
# Out:
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geounit_df['Quarter'] = geounit_df['Adjusted Date'].dt.to_period('Q')
# Learning rate set to 0.038834
# 0:	learn: 0.1345850	test: 0.0980189	best: 0.0980189 (0)	total: 204ms	remaining: 3m 23s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.07142346046
# bestIteration = 38
#
# Shrink model to first 39 iterations.
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Predicted'] = test_preds
# Quarterly Test Data for APG:
#   Quarter  Operating_CellMonth  Predicted  Percentage_Error
# 0  2024Q1             4.396017   5.987754         36.208608
# 1  2024Q2             3.951161   4.796251         21.388398
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geounit_df['Quarter'] = geounit_df['Adjusted Date'].dt.to_period('Q')
# Learning rate set to 0.032386
# 0:	learn: 0.2036438	test: 0.1723885	best: 0.1723885 (0)	total: 121ms	remaining: 2m
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.1581609865
# bestIteration = 30
#
# Shrink model to first 31 iterations.
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Predicted'] = test_preds
# Quarterly Test Data for QTG:
#   Quarter  Operating_CellMonth  Predicted  Percentage_Error
# 0  2024Q1             3.728291   3.845192          3.135528
# 1  2024Q2             2.601075   2.546361         -2.103527
# Learning rate set to 0.041766
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geounit_df['Quarter'] = geounit_df['Adjusted Date'].dt.to_period('Q')
# 0:	learn: 0.0568705	test: 0.0540776	best: 0.0540776 (0)	total: 67.1ms	remaining: 1m 7s
# 100:	learn: 0.0456495	test: 0.0518901	best: 0.0517561 (57)	total: 9.3s	remaining: 1m 22s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.05175606181
# bestIteration = 57
#
# Shrink model to first 58 iterations.
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Predicted'] = test_preds
# Quarterly Test Data for ECP:
#   Quarter  Operating_CellMonth  Predicted  Percentage_Error
# 0  2024Q1             3.757694   4.070853          8.333804
# 1  2024Q2             4.910378   4.747375         -3.319565
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geounit_df['Quarter'] = geounit_df['Adjusted Date'].dt.to_period('Q')
# Learning rate set to 0.034047
# 0:	learn: 0.0646122	test: 0.0757295	best: 0.0757295 (0)	total: 274ms	remaining: 4m 33s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.07566431793
# bestIteration = 15
#
# Shrink model to first 16 iterations.
# C:\Users\IWahbi\AppData\Local\Temp\ipykernel_51904\3197246903.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Predicted'] = test_preds
# Quarterly Test Data for NAO:
#   Quarter  Operating_CellMonth  Predicted  Percentage_Error
# 0  2024Q1             1.569522   1.453462         -7.394579
# 1  2024Q2             2.460215   2.139141        -13.050656
# Feature Importance for APG:
#              feature  importance
# 4  Unique_Well_Count   82.892985
# 0       Country Name   11.588173
# 3          Well type    4.096218
# 2           Rig Name    1.033437
# 1    Billing Account    0.389187
# Feature Importance for QTG:
#              feature  importance
# 3          Well type   73.361535
# 1    Billing Account   19.640241
# 2           Rig Name    5.865697
# 4  Unique_Well_Count    1.132527
# 0       Country Name    0.000000
# Feature Importance for ECP:
#              feature  importance
# 4  Unique_Well_Count   45.959493
# 1    Billing Account   17.929227
# 0       Country Name   14.742029
# 2           Rig Name   13.469785
# 3          Well type    7.899466
# Feature Importance for NAO:
#              feature  importance
# 1    Billing Account   40.057521
# 3          Well type   33.823648
# 2           Rig Name   20.733153
# 4  Unique_Well_Count    2.830027
# 0       Country Name    2.555651
